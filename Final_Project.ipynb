# %%
import pandas as pd

sp = pd.read_csv('SP500_Daily_Returns.csv')
print(sp)
# Out:
#             Date        D0        D1      Volume        R1
# 0       1/3/2000  1,455.22  1,399.42   931800000 -0.038345
# 1       1/4/2000  1,399.42  1,402.11  1009000000  0.001922
# 2       1/5/2000  1,402.11  1,403.45  1085500000  0.000956
# 3       1/6/2000  1,403.45  1,441.47  1092300000  0.027090
# 4       1/7/2000  1,441.47  1,457.60  1225200000  0.011190
# ...          ...       ...       ...         ...       ...
# 6031  12/22/2023   4754.63  4,774.75  3046770000  0.004232
# 6032  12/26/2023   4774.75  4,781.58  2513910000  0.001430
# 6033  12/27/2023   4781.58  4,783.35  2748450000  0.000370
# 6034  12/28/2023   4783.35  4,769.83  2698860000 -0.002826
# 6035  12/29/2023   4769.83  4,742.83  3126060000 -0.005661
#
# [6036 rows x 5 columns]

# %%
import pandas as pd

sentiment = pd.read_csv(
    'alexandria_sentiment_train.csv',sep='\t',usecols=['StoryID', 'Timestamp', 'Economy', 'Sentiment', 'Confidence', 'Novelty', 'Events', 'Source'])

sentiment = sentiment[sentiment['Economy'] == 'AE@USA']
print(sentiment.shape)
print(sentiment.head())
# Out:
# (6525567, 8)
#                              StoryID                Timestamp Economy  \
# 0   ZDM4QldGVmNTUUlFQVFRREFRZFlYdz09  2000-01-01 00:15:37.000  AE@USA
# 1   ZDM4QldGVmNTUUlFQVFRREFRZFlXUT09  2000-01-01 00:26:38.000  AE@USA
# 3   ZDM4QldGVmNTUUlFQVFRREFRZFlXZz09  2000-01-01 00:56:22.000  AE@USA
# 10  ZDM4QldGVmNTUUlFQVFRREFRaFJWUT09  2000-01-01 04:35:07.000  AE@USA
# 11  ZDM4QldGVmNTUUlFQVFRREFRaFFWUT09  2000-01-01 04:52:00.000  AE@USA
#
#     Sentiment  Confidence  Novelty          Events Source
# 0           1    0.844671        1  EE@ALEX,EE@CPT    DJN
# 1           0    0.930665        2  EE@ALEX,EE@GOV    DJN
# 3           0    0.760198        1         EE@ALEX    DJN
# 10          0    0.904325        1         EE@ALEX    DJN
# 11          0    0.951480        1         EE@ALEX    DJN
